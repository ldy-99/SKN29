# %%
import pandas as pd
file_path = '20220207.csv'
df = pd.read_csv(file_path,encoding='cp949')
df.head()
#df.isnull().sum()
df.rename(columns = {'단속원금(원)' : '단속원금'} , inplace=True)
df.sort_values(by=['단속원금'],ascending=False).iloc[:5]
df['연도'].min() , df['연도'].max()
# Out:
# (2017, 2021)
