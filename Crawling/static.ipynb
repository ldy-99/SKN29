# %%
# %conda install requests beautifulsoup4 lxml selenium

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://example.com/'
response = requests.get(url)

response.text
soup = BeautifulSoup(response.text , 'lxml')
title = soup.find('h1').text
print(title)
# Out:
# 'Example Domain'
